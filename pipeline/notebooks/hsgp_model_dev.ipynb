# %% [markdown]
# # HSGP Model Development
#
# Spatio-temporal Gaussian Process for Nordic grid zones.
#
# ## Phase 1 tasks
#
# 1. Load synthetic weather data from PostgreSQL
# 2. Build HSGP with PyMC `pm.gp.HSGP` (Matern 3/2 spatial + 5/2 temporal)
# 3. Fit with SVI (ADVI or NumPyro)
# 4. Validate: compare learned spatial correlation to true
# 5. Generate tail-risk forecasts, verify they flag synthetic drought events

# %%
import pandas as pd
import numpy as np

# TODO: Load from PostgreSQL or Parquet
# from pipeline.model.feature_engineering import prepare_hsgp_input
# from pipeline.model.hsgp_model import build_hsgp_model, train_hsgp
